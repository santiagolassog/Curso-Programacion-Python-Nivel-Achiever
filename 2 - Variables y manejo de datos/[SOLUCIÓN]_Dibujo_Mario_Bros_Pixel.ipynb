# %%
# Intalación de librería
# !pip install ColabTurtlePlus

# Importación de librería:
import ColabTurtlePlus.Turtle as t

# %%
"""-------------------------------
# Configuración de ventana
-------------------------------"""
t.clearscreen()
t.setup(200,200)
t.shape("arrow")
t.speed(13)

# Declaración de variables
"""--------------------------------
Colores originales:
-----------------------------------
color_gorra = "#f90e01"
color_cara_manos = "#fddb83"
color_cabello_zapatos = "#a12a26"
color_ojos_boca = "#000000"
color_camisa = "#f90e01"
color_overol = "#0301fb"
color_botones = "#fdfd03"
-----------------------------------
Colores modificados:
--------------------------------"""
color_gorra = "#44B01B"
color_cara_manos = "#FEC99A"
color_cabello_zapatos = "#4D0402"
color_ojos_boca = "#000000"
color_camisa = "#47B918"
color_overol = "#2F5082"
color_botones = "#FFEA05"

"""-------------------------------
# Dibujo de la gorra
-------------------------------"""
t.jumpto(-30,80)
t.color(color_gorra)
t.fillcolor(color_gorra)
t.begin_fill()
t.fd(60)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(40)
t.rt(90)
t.fd(10)
t.rt(90)
t.fd(110)
t.rt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.end_fill()

"""-------------------------------
# Dibujo de la cara
-------------------------------"""
t.rt(180)
t.jumpto(-40,60)
t.color(color_cara_manos)
t.fillcolor(color_cara_manos)
t.begin_fill()
t.fd(30)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(20)
t.lt(90)
t.fd(80)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(20)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(80)
t.end_fill()

"""-------------------------------
# Dibujo del cabello
-------------------------------"""
t.lt(90)
t.color(color_cabello_zapatos)
t.fillcolor(color_cabello_zapatos)
t.begin_fill()
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(20)
t.lt(90)
t.fd(20)
t.lt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.lt(90)
t.fd(30)
t.end_fill()
t.begin_fill()
t.lt(90)
t.fd(30)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(30)
t.rt(90)
t.fd(10)
t.end_fill()

"""-------------------------------
# Dibujo de ojos y boca
-------------------------------"""
t.jumpto(20,60)
t.color(color_ojos_boca)
t.fillcolor(color_ojos_boca)
t.begin_fill()
t.fd(10)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(10)
t.rt(90)
t.fd(20)
t.end_fill()
t.jumpto(30,40)
t.begin_fill()
t.rt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.end_fill()
t.jumpto(30,30)
t.begin_fill()
t.lt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.lt(90)
t.fd(40)
t.lt(90)
t.fd(10)
t.lt(90)
t.fd(20)
t.end_fill()

"""-------------------------------
# Dibujo de camisa
-------------------------------"""
t.jumpto(10,10)
t.color(color_camisa)
t.fillcolor(color_camisa)
t.begin_fill()
t.fd(50)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.lt(90)
t.fd(20)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(40)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(20)
t.lt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(30)
t.end_fill()

"""-------------------------------
# Dibujo de overol
-------------------------------"""
t.jumpto(20,10)
t.color(color_overol)
t.fillcolor(color_overol)
t.begin_fill()
t.lt(90)
t.fd(30)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(20)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(30)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(20)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(30)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(20)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(30)
t.rt(90)
t.fd(40)
t.end_fill()

"""-------------------------------
# Dibujo resto de camisa y botones
-------------------------------"""
t.jumpto(20,-20)
t.color(color_botones)
t.fillcolor(color_botones)
t.begin_fill()
t.rt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.end_fill()
t.jumpto(-10,-20)
t.begin_fill()
t.rt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.end_fill()
t.jumpto(10,10)

# Resto de la camisa
t.color(color_camisa)
t.fillcolor(color_camisa)
t.begin_fill()
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(20)
t.end_fill()

"""-------------------------------
# Dibujo de manos
-------------------------------"""
t.jumpto(-30,-30)
t.color(color_cara_manos)
t.fillcolor(color_cara_manos)
t.begin_fill()
t.rt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(30)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.end_fill()
t.jumpto(30,-30)
t.color(color_cara_manos)
t.fillcolor(color_cara_manos)
t.begin_fill()
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(30)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.end_fill()

"""-------------------------------
# Dibujo de zapatos
-------------------------------"""
t.jumpto(-20,-60)
t.color(color_cabello_zapatos)
t.fillcolor(color_cabello_zapatos)
t.begin_fill()
t.lt(90)
t.fd(30)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.lt(90)
t.fd(40)
t.lt(90)
t.fd(20)
t.end_fill()
t.jumpto(20,-60)
t.begin_fill()
t.rt(90)
t.fd(30)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.rt(90)
t.fd(40)
t.rt(90)
t.fd(20)
t.end_fill()

"""-------------------------------
# FIN DEL DIBUJO
-------------------------------"""
t.ht()
