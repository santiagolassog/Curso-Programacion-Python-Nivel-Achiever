# %%
# Intalación de librería
# !pip install ColabTurtlePlus

# Importación de librería:
import ColabTurtlePlus.Turtle as t

# %%
# Configuración de ventana
t.clearscreen()
t.setup(200,200)
t.shape("arrow")
t.speed(13)

"""-------------------------------
# Dibujo de la gorra
-------------------------------"""
t.jumpto(-30,80)
t.color("#f90e01")
t.fillcolor("#f90e01")
t.begin_fill()
t.fd(60)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(40)
t.rt(90)
t.fd(10)
t.rt(90)
t.fd(110)
t.rt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.end_fill()

"""-------------------------------
# Dibujo de la cara
-------------------------------"""
t.rt(180)
t.jumpto(-40,60)
t.color("#fddb83")
t.fillcolor("#fddb83")
t.begin_fill()
t.fd(30)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(20)
t.lt(90)
t.fd(80)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(20)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(80)
t.end_fill()

"""-------------------------------
# Dibujo del cabello
-------------------------------"""
t.lt(90)
t.color("#a12a26")
t.fillcolor("#a12a26")
t.begin_fill()
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(20)
t.lt(90)
t.fd(20)
t.lt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.lt(90)
t.fd(30)
t.end_fill()
t.begin_fill()
t.lt(90)
t.fd(30)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(30)
t.rt(90)
t.fd(10)
t.end_fill()

"""-------------------------------
# Dibujo de ojos y boca
-------------------------------"""
t.jumpto(20,60)
t.color("#000000")
t.fillcolor("#000000")
t.begin_fill()
t.fd(10)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(10)
t.rt(90)
t.fd(20)
t.end_fill()
t.jumpto(30,40)
t.begin_fill()
t.rt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.end_fill()
t.jumpto(30,30)
t.begin_fill()
t.lt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.lt(90)
t.fd(40)
t.lt(90)
t.fd(10)
t.lt(90)
t.fd(20)
t.end_fill()

"""-------------------------------
# Dibujo de camisa
-------------------------------"""
t.jumpto(10,10)
t.color("#f90e01")
t.fillcolor("#f90e01")
t.begin_fill()
t.fd(50)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.lt(90)
t.fd(20)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(40)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(20)
t.lt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(30)
t.end_fill()

"""-------------------------------
# Dibujo de overol
-------------------------------"""
t.jumpto(20,10)
t.color("#0301fb")
t.fillcolor("#0301fb")
t.begin_fill()
t.lt(90)
t.fd(30)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(20)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(30)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(20)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(30)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(20)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(30)
t.rt(90)
t.fd(40)
t.end_fill()

"""-------------------------------
# Dibujo resto de overol y botones
-------------------------------"""
t.jumpto(20,-20)
t.color("#fdfe00")
t.fillcolor("#fdfe00")
t.begin_fill()
t.rt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.end_fill()
t.jumpto(-10,-20)
t.begin_fill()
t.rt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.end_fill()
t.jumpto(10,10)
t.color("#f90e01")
t.fillcolor("#f90e01")
t.begin_fill()
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(20)
t.end_fill()

"""-------------------------------
# Dibujo de manos
-------------------------------"""
t.jumpto(-30,-30)
t.color("#fddb83")
t.fillcolor("#fddb83")
t.begin_fill()
t.rt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(30)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.end_fill()
t.jumpto(30,-30)
t.color("#fddb83")
t.fillcolor("#fddb83")
t.begin_fill()
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(30)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.end_fill()
"""-------------------------------
# Dibujo de zapatos
-------------------------------"""
t.jumpto(-20,-60)
t.color("#a12a26")
t.fillcolor("#a12a26")
t.begin_fill()
t.lt(90)
t.fd(30)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.lt(90)
t.fd(40)
t.lt(90)
t.fd(20)
t.end_fill()
t.jumpto(20,-60)
t.begin_fill()
t.rt(90)
t.fd(30)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.rt(90)
t.fd(40)
t.rt(90)
t.fd(20)
t.end_fill()

"""-------------------------------
# FIN DEL DIBUJO
-------------------------------"""
t.ht()
