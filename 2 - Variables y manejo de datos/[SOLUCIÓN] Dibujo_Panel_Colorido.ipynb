# %%
"""-------------------------------
# Instación e importación librería
-------------------------------"""
# !pip install ColabTurtlePlus
import ColabTurtlePlus.Turtle as t

# %%
"""----------------------------
# Declaración de variables
----------------------------"""
size = 30
ancho = 200
alto = 200

"""----------------------------
# Configuración de ventana
----------------------------"""
t.clearscreen()
t.setup(ancho,alto)
t.shape("turtle")
t.color("black")
t.speed(13)

t.jumpto(-60,50)

"""----------------------------
# Hexágono Azul 1
----------------------------"""
t.fillcolor("#44c0f9")
t.begin_fill()
t.fd(size)
t.rt(60)
t.fd(size)
t.rt(60)
t.fd(size)
t.rt(60)
t.fd(size)
t.rt(60)
t.fd(size)
t.rt(60)
t.fd(size)
t.rt(60)
t.fd(size)
t.end_fill()

"""----------------------------
# Hexágono Amarillo 1
----------------------------"""
t.lt(60)
t.fillcolor("#d9d858")
t.begin_fill()
t.fd(size)
t.rt(60)
t.fd(size)
t.rt(60)
t.fd(size)
t.rt(60)
t.fd(size)
t.rt(60)
t.fd(size)
t.end_fill()

"""----------------------------
# Hexágono Central Rojo
----------------------------"""
t.lt(180)
t.fillcolor("#e45f56")
t.begin_fill()
t.fd(size)
t.rt(60)
t.fd(size)
t.rt(60)
t.fd(size)
t.rt(60)
t.fd(size)
t.rt(60)
t.fd(size)
t.rt(60)
t.fd(size)
t.rt(60)
t.fd(size)
t.end_fill()

"""----------------------------
# Hexágono Verde 1
----------------------------"""
t.lt(60)
t.fillcolor("#7ed957")
t.begin_fill()
t.fd(size)
t.rt(60)
t.fd(size)
t.rt(60)
t.fd(size)
t.rt(60)
t.fd(size)
t.rt(60)
t.fd(size)
t.end_fill()

"""----------------------------
# Hexágono Azul 2
----------------------------"""
t.lt(180)
t.fillcolor("#44c0f9")
t.begin_fill()
t.fd(size)
t.rt(60)
t.fd(size)
t.rt(60)
t.fd(size)
t.rt(60)
t.fd(size)
t.rt(60)
t.fd(size)
t.rt(60)
t.fd(size)
t.rt(60)
t.end_fill()

"""----------------------------
# Hexágono Amarillo 2
----------------------------"""
t.lt(180)
t.lt(60)
t.fd(size)
t.lt(60)
t.fillcolor("#d9d858")
t.begin_fill()
t.fd(size)
t.rt(60)
t.fd(size)
t.rt(60)
t.fd(size)
t.rt(60)
t.fd(size)
t.rt(60)
t.fd(size)
t.rt(60)
t.end_fill()

"""----------------------------
# Hexágono Verde 2
----------------------------"""
t.lt(180)
t.fillcolor("#7ed957")
t.begin_fill()
t.rt(60)
t.fd(size)
t.lt(60)
t.fd(size)
t.lt(60)
t.fd(size)
t.lt(60)
t.fd(size)
t.lt(60)
t.fd(size)
t.lt(60)
t.fd(size)
t.end_fill()

"""----------------------------
# Fin del dibujo
----------------------------"""
t.ht()
